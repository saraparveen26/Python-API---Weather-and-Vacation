# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import time
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the starter code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define units to get the temperature in Celsius
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

            # Note: I used pprint to review the response
            # pprint(city_weather)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | la ronge
# Processing Record 5 of Set 1 | ushtobe
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | pontes e lacerda
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | bolkhov
# Processing Record 14 of Set 1 | torquay
# Processing Record 15 of Set 1 | kautokeino
# Processing Record 16 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | karratha
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | lhokseumawe
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | phalodi
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | upernavik
# Processing Record 25 of Set 1 | esna
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | husavik
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | tahoua
# Processing Record 31 of Set 1 | santa rita
# Processing Record 32 of Set 1 | miyang
# Processing Record 33 of Set 1 | viedma
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | meulaboh
# Processing Record 37 of Set 1 | college
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | guajara
# Processing Record 41 of Set 1 | gayeri
# Processing Record 42 of Set 1 | andenes
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | independence
# Processing Record 45 of Set 1 | nhulunbuy
# Processing Record 46 of Set 1 | merauke
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 1 | thinadhoo
# Processing Record 50 of Set 1 | victoria
# Processing Record 0 of Set 2 | richards bay
# Processing Record 1 of Set 2 | turayf
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | hanzhong
# Processing Record 4 of Set 2 | kosino
# Processing Record 5 of Set 2 | saldanha
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | komsomolskiy
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | sistranda
# Processing Record 12 of Set 2 | tuatapere
# Processing Record 13 of Set 2 | turukhansk
# Processing Record 14 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 2 | mikhaylov
# Processing Record 16 of Set 2 | tinde
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | alofi
# Processing Record 20 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 2 | kenora
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | batemans bay
# Processing Record 24 of Set 2 | gold coast
# Processing Record 25 of Set 2 | rio brilhante
# Processing Record 26 of Set 2 | ushuaia
# Processing Record 27 of Set 2 | omboue
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | north bend
# Processing Record 31 of Set 2 | kaitangata
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | cocobeach
# Processing Record 34 of Set 2 | sorland
# Processing Record 35 of Set 2 | wetteren
# Processing Record 36 of Set 2 | saint-georges
# Processing Record 37 of Set 2 | kenai
# Processing Record 38 of Set 2 | russell
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | namibe
# Processing Record 41 of Set 2 | severo-kurilsk
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | alice springs
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | tenenkou
# Processing Record 48 of Set 2 | akyab
# Processing Record 49 of Set 2 | pangnirtung
# Processing Record 0 of Set 3 | vostok
# Processing Record 1 of Set 3 | port blair
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | atar
# Processing Record 5 of Set 3 | gemena
# Processing Record 6 of Set 3 | winneba
# Processing Record 7 of Set 3 | severnyy
# Processing Record 8 of Set 3 | iskateley
# Processing Record 9 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 3 | dingle
# Processing Record 11 of Set 3 | mayo
# Processing Record 12 of Set 3 | mehamn
# Processing Record 13 of Set 3 | coos bay
# Processing Record 14 of Set 3 | jacala
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | maun
# Processing Record 17 of Set 3 | mildura
# Processing Record 18 of Set 3 | porto novo
# Processing Record 19 of Set 3 | gat
# Processing Record 20 of Set 3 | springbok
# Processing Record 21 of Set 3 | khatanga
# Processing Record 22 of Set 3 | leningradskiy
# Processing Record 23 of Set 3 | clayton
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | beloha
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | berlevag
# Processing Record 30 of Set 3 | sao filipe
# Processing Record 31 of Set 3 | terra santa
# Processing Record 32 of Set 3 | cayenne
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | chengmai
# City not found. Skipping...
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | dunedin
# Processing Record 37 of Set 3 | domna
# Processing Record 38 of Set 3 | kamenka
# Processing Record 39 of Set 3 | fairbanks
# Processing Record 40 of Set 3 | sinnamary
# Processing Record 41 of Set 3 | antofagasta
# Processing Record 42 of Set 3 | grindavik
# Processing Record 43 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 3 | garissa
# Processing Record 45 of Set 3 | port macquarie
# Processing Record 46 of Set 3 | darhan
# Processing Record 47 of Set 3 | chuy
# Processing Record 48 of Set 3 | brae
# Processing Record 49 of Set 3 | oga
# Processing Record 0 of Set 4 | hilo
# Processing Record 1 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 4 | rosetta
# Processing Record 3 of Set 4 | biak
# Processing Record 4 of Set 4 | muscat
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | shimoda
# Processing Record 7 of Set 4 | prado
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | mecca
# Processing Record 10 of Set 4 | ridgecrest
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 4 | ternate
# Processing Record 14 of Set 4 | yabrud
# Processing Record 15 of Set 4 | te anau
# Processing Record 16 of Set 4 | laguna
# Processing Record 17 of Set 4 | mzimba
# Processing Record 18 of Set 4 | ust-nera
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 4 | deputatskiy
# Processing Record 22 of Set 4 | birjand
# Processing Record 23 of Set 4 | sabya
# Processing Record 24 of Set 4 | gizo
# Processing Record 25 of Set 4 | bredasdorp
# Processing Record 26 of Set 4 | honiara
# Processing Record 27 of Set 4 | phrai bung
# City not found. Skipping...
# Processing Record 28 of Set 4 | meadow lake
# Processing Record 29 of Set 4 | lompoc
# Processing Record 30 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 31 of Set 4 | moron
# Processing Record 32 of Set 4 | alagir
# Processing Record 33 of Set 4 | egvekinot
# Processing Record 34 of Set 4 | port alfred
# Processing Record 35 of Set 4 | anadyr
# Processing Record 36 of Set 4 | hasaki
# Processing Record 37 of Set 4 | skjaerhollen
# City not found. Skipping...
# Processing Record 38 of Set 4 | porbandar
# Processing Record 39 of Set 4 | shwebo
# Processing Record 40 of Set 4 | rosignano marittimo
# Processing Record 41 of Set 4 | kabare
# Processing Record 42 of Set 4 | plettenberg bay
# Processing Record 43 of Set 4 | aykhal
# Processing Record 44 of Set 4 | nemuro
# Processing Record 45 of Set 4 | paamiut
# Processing Record 46 of Set 4 | dikson
# Processing Record 47 of Set 4 | buritica
# Processing Record 48 of Set 4 | gangapur
# Processing Record 49 of Set 4 | cururupu
# Processing Record 0 of Set 5 | dakar
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | milkovo
# Processing Record 4 of Set 5 | kholodnyy
# Processing Record 5 of Set 5 | tezu
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | sioux lookout
# Processing Record 8 of Set 5 | beringovskiy
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 10 of Set 5 | nabire
# Processing Record 11 of Set 5 | cockburn town
# Processing Record 12 of Set 5 | noyabrsk
# Processing Record 13 of Set 5 | grande-riviere
# City not found. Skipping...
# Processing Record 14 of Set 5 | narsaq
# Processing Record 15 of Set 5 | saryg-sep
# Processing Record 16 of Set 5 | ta khmau
# Processing Record 17 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 5 | miles city
# Processing Record 19 of Set 5 | ivanteyevka
# Processing Record 20 of Set 5 | awbari
# Processing Record 21 of Set 5 | sinop
# Processing Record 22 of Set 5 | soloneshnoye
# Processing Record 23 of Set 5 | nome
# Processing Record 24 of Set 5 | katobu
# Processing Record 25 of Set 5 | tateyama
# Processing Record 26 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 5 | matara
# Processing Record 28 of Set 5 | coahuayana
# Processing Record 29 of Set 5 | esperance
# Processing Record 30 of Set 5 | hualmay
# Processing Record 31 of Set 5 | sao paulo de olivenca
# Processing Record 32 of Set 5 | merta
# Processing Record 33 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 5 | tautira
# Processing Record 35 of Set 5 | asau
# Processing Record 36 of Set 5 | marechal candido rondon
# Processing Record 37 of Set 5 | seoul
# Processing Record 38 of Set 5 | waipawa
# Processing Record 39 of Set 5 | ust-omchug
# Processing Record 40 of Set 5 | pochutla
# Processing Record 41 of Set 5 | gouyave
# Processing Record 42 of Set 5 | bucerias
# Processing Record 43 of Set 5 | ullapool
# Processing Record 44 of Set 5 | riverton
# Processing Record 45 of Set 5 | pedernales
# Processing Record 46 of Set 5 | katsuura
# Processing Record 47 of Set 5 | chapada dos guimaraes
# Processing Record 48 of Set 5 | atasu
# Processing Record 49 of Set 5 | copperas cove
# Processing Record 0 of Set 6 | olafsvik
# Processing Record 1 of Set 6 | nioro
# Processing Record 2 of Set 6 | san patricio
# Processing Record 3 of Set 6 | iqaluit
# Processing Record 4 of Set 6 | pran buri
# Processing Record 5 of Set 6 | airai
# Processing Record 6 of Set 6 | puerto escondido
# Processing Record 7 of Set 6 | randudongkal
# Processing Record 8 of Set 6 | oranjemund
# Processing Record 9 of Set 6 | nikolskoye
# Processing Record 10 of Set 6 | manjeri
# Processing Record 11 of Set 6 | mega
# Processing Record 12 of Set 6 | sabha
# Processing Record 13 of Set 6 | sao joao da barra
# Processing Record 14 of Set 6 | melo
# Processing Record 15 of Set 6 | atlantic city
# Processing Record 16 of Set 6 | san quintin
# Processing Record 17 of Set 6 | pombia
# Processing Record 18 of Set 6 | lata
# Processing Record 19 of Set 6 | guarapari
# Processing Record 20 of Set 6 | kirakira
# Processing Record 21 of Set 6 | mehran
# Processing Record 22 of Set 6 | madang
# Processing Record 23 of Set 6 | guasdualito
# Processing Record 24 of Set 6 | cotonou
# Processing Record 25 of Set 6 | hajipur
# Processing Record 26 of Set 6 | tazovskiy
# Processing Record 27 of Set 6 | puerto quijarro
# Processing Record 28 of Set 6 | itoman
# Processing Record 29 of Set 6 | dalbandin
# Processing Record 30 of Set 6 | porto santo
# Processing Record 31 of Set 6 | saint anthony
# Processing Record 32 of Set 6 | batticaloa
# Processing Record 33 of Set 6 | fairlie
# Processing Record 34 of Set 6 | vincennes
# Processing Record 35 of Set 6 | xicotencatl
# Processing Record 36 of Set 6 | marsala
# Processing Record 37 of Set 6 | vanavara
# Processing Record 38 of Set 6 | beira
# Processing Record 39 of Set 6 | abatskoye
# Processing Record 40 of Set 6 | bulawayo
# Processing Record 41 of Set 6 | palmer
# Processing Record 42 of Set 6 | bengkulu
# Processing Record 43 of Set 6 | ilulissat
# Processing Record 44 of Set 6 | the valley
# Processing Record 45 of Set 6 | lumajang
# Processing Record 46 of Set 6 | cangucu
# Processing Record 47 of Set 6 | san francisco
# Processing Record 48 of Set 6 | klaksvik
# Processing Record 49 of Set 6 | copiapo
# Processing Record 0 of Set 7 | lavrentiya
# Processing Record 1 of Set 7 | qunduz
# Processing Record 2 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 7 | anito
# Processing Record 5 of Set 7 | kropotkin
# Processing Record 6 of Set 7 | groningen
# Processing Record 7 of Set 7 | broome
# Processing Record 8 of Set 7 | jackson
# Processing Record 9 of Set 7 | vila franca do campo
# Processing Record 10 of Set 7 | ambon
# Processing Record 11 of Set 7 | dingzhou
# Processing Record 12 of Set 7 | makakilo city
# Processing Record 13 of Set 7 | faanui
# Processing Record 14 of Set 7 | ancud
# Processing Record 15 of Set 7 | adrar
# Processing Record 16 of Set 7 | magdagachi
# Processing Record 17 of Set 7 | rio verde de mato grosso
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | morondava
# Processing Record 20 of Set 7 | tasiilaq
# Processing Record 21 of Set 7 | mount gambier
# Processing Record 22 of Set 7 | sitka
# Processing Record 23 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 7 | saint-francois
# Processing Record 25 of Set 7 | kununurra
# Processing Record 26 of Set 7 | takoradi
# Processing Record 27 of Set 7 | ca mau
# Processing Record 28 of Set 7 | nanzhou
# Processing Record 29 of Set 7 | port augusta
# Processing Record 30 of Set 7 | hami
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | arrecife
# Processing Record 34 of Set 7 | honningsvag
# Processing Record 35 of Set 7 | conselheiro lafaiete
# Processing Record 36 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 7 | qarqin
# Processing Record 38 of Set 7 | vestmanna
# Processing Record 39 of Set 7 | barcelona
# Processing Record 40 of Set 7 | davila
# Processing Record 41 of Set 7 | taikang
# Processing Record 42 of Set 7 | grants pass
# Processing Record 43 of Set 7 | yulara
# Processing Record 44 of Set 7 | wegorzewo
# Processing Record 45 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 7 | le vauclin
# Processing Record 47 of Set 7 | balkanabat
# Processing Record 48 of Set 7 | alta floresta
# Processing Record 49 of Set 7 | aklavik
# Processing Record 0 of Set 8 | papayal
# Processing Record 1 of Set 8 | lumphat
# Processing Record 2 of Set 8 | evensk
# Processing Record 3 of Set 8 | korla
# Processing Record 4 of Set 8 | mazatlan
# Processing Record 5 of Set 8 | bichura
# Processing Record 6 of Set 8 | somerset
# Processing Record 7 of Set 8 | necochea
# Processing Record 8 of Set 8 | naerbo
# Processing Record 9 of Set 8 | barabai
# Processing Record 10 of Set 8 | santa vitoria do palmar
# Processing Record 11 of Set 8 | sudak
# Processing Record 12 of Set 8 | lincolnton
# Processing Record 13 of Set 8 | osa
# Processing Record 14 of Set 8 | santa lucia
# Processing Record 15 of Set 8 | donskoye
# Processing Record 16 of Set 8 | raudeberg
# Processing Record 17 of Set 8 | nabinagar
# Processing Record 18 of Set 8 | jumla
# Processing Record 19 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 8 | baneh
# Processing Record 21 of Set 8 | balotra
# Processing Record 22 of Set 8 | ayan
# Processing Record 23 of Set 8 | paita
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | ilhabela
# Processing Record 26 of Set 8 | phayao
# Processing Record 27 of Set 8 | multan
# Processing Record 28 of Set 8 | brigantine
# Processing Record 29 of Set 8 | taltal
# Processing Record 30 of Set 8 | norman wells
# Processing Record 31 of Set 8 | ampanihy
# Processing Record 32 of Set 8 | umm lajj
# Processing Record 33 of Set 8 | belyy yar
# Processing Record 34 of Set 8 | shenjiamen
# Processing Record 35 of Set 8 | boyarka
# Processing Record 36 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 8 | kaeo
# Processing Record 38 of Set 8 | lashio
# Processing Record 39 of Set 8 | gornopravdinsk
# Processing Record 40 of Set 8 | codrington
# Processing Record 41 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 8 | kindersley
# Processing Record 43 of Set 8 | sola
# Processing Record 44 of Set 8 | labuhan
# Processing Record 45 of Set 8 | khatassy
# Processing Record 46 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 47 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 8 | kailua
# Processing Record 49 of Set 8 | itarema
# Processing Record 0 of Set 9 | areka
# Processing Record 1 of Set 9 | solikamsk
# Processing Record 2 of Set 9 | tuy hoa
# Processing Record 3 of Set 9 | kuryk
# Processing Record 4 of Set 9 | finschhafen
# Processing Record 5 of Set 9 | poronaysk
# Processing Record 6 of Set 9 | alegrete
# Processing Record 7 of Set 9 | agadez
# Processing Record 8 of Set 9 | auki
# Processing Record 9 of Set 9 | micheweni
# Processing Record 10 of Set 9 | douentza
# Processing Record 11 of Set 9 | shahr-e kord
# Processing Record 12 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 9 | aksaray
# Processing Record 14 of Set 9 | pevek
# Processing Record 15 of Set 9 | floro
# Processing Record 16 of Set 9 | kropachevo
# Processing Record 17 of Set 9 | altamira
# Processing Record 18 of Set 9 | dabra
# Processing Record 19 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 9 | malanje
# Processing Record 21 of Set 9 | hovd
# Processing Record 22 of Set 9 | arraial do cabo
# Processing Record 23 of Set 9 | gurjaani
# Processing Record 24 of Set 9 | cabinda
# Processing Record 25 of Set 9 | abay
# Processing Record 26 of Set 9 | amudat
# Processing Record 27 of Set 9 | marsh harbour
# Processing Record 28 of Set 9 | tiznit
# Processing Record 29 of Set 9 | guerrero negro
# Processing Record 30 of Set 9 | surubim
# Processing Record 31 of Set 9 | marawi
# Processing Record 32 of Set 9 | tabuk
# Processing Record 33 of Set 9 | butembo
# Processing Record 34 of Set 9 | sur
# Processing Record 35 of Set 9 | trojes
# Processing Record 36 of Set 9 | kimberley
# Processing Record 37 of Set 9 | bar harbor
# Processing Record 38 of Set 9 | sapele
# Processing Record 39 of Set 9 | la libertad
# Processing Record 40 of Set 9 | kasongo
# Processing Record 41 of Set 9 | badarwas
# Processing Record 42 of Set 9 | santa maria da vitoria
# Processing Record 43 of Set 9 | feltre
# Processing Record 44 of Set 9 | arroio grande
# Processing Record 45 of Set 9 | trencin
# Processing Record 46 of Set 9 | constitucion
# Processing Record 47 of Set 9 | bandarbeyla
# Processing Record 48 of Set 9 | kavieng
# Processing Record 49 of Set 9 | sabang
# Processing Record 0 of Set 10 | mporokoso
# Processing Record 1 of Set 10 | vanimo
# Processing Record 2 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 3 of Set 10 | khandagayty
# Processing Record 4 of Set 10 | bismil
# Processing Record 5 of Set 10 | sambava
# Processing Record 6 of Set 10 | canberra
# Processing Record 7 of Set 10 | dzhebariki-khaya
# Processing Record 8 of Set 10 | praia da vitoria
# Processing Record 9 of Set 10 | vestmannaeyjar
# Processing Record 10 of Set 10 | upata
# Processing Record 11 of Set 10 | san vicente
# Processing Record 12 of Set 10 | george town
# Processing Record 13 of Set 10 | thai binh
# Processing Record 14 of Set 10 | remedios
# Processing Record 15 of Set 10 | kambove
# Processing Record 16 of Set 10 | asfi
# Processing Record 17 of Set 10 | hay river
# Processing Record 18 of Set 10 | hobyo
# Processing Record 19 of Set 10 | coihaique
# Processing Record 20 of Set 10 | neuquen
# Processing Record 21 of Set 10 | fuerte olimpo
# Processing Record 22 of Set 10 | wenling
# Processing Record 23 of Set 10 | foix
# Processing Record 24 of Set 10 | dapaong
# Processing Record 25 of Set 10 | taoudenni
# Processing Record 26 of Set 10 | ahipara
# Processing Record 27 of Set 10 | hambantota
# Processing Record 28 of Set 10 | rio gallegos
# Processing Record 29 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 30 of Set 10 | olga
# Processing Record 31 of Set 10 | lebyazhye
# Processing Record 32 of Set 10 | roma
# Processing Record 33 of Set 10 | nurpur
# Processing Record 34 of Set 10 | road town
# Processing Record 35 of Set 10 | maurawan
# Processing Record 36 of Set 10 | chicama
# Processing Record 37 of Set 10 | buala
# Processing Record 38 of Set 10 | chipata
# Processing Record 39 of Set 10 | prieska
# Processing Record 40 of Set 10 | kruisfontein
# Processing Record 41 of Set 10 | huilong
# Processing Record 42 of Set 10 | iquitos
# Processing Record 43 of Set 10 | valkla
# Processing Record 44 of Set 10 | gongzhuling
# Processing Record 45 of Set 10 | zafra
# Processing Record 46 of Set 10 | santa cruz
# Processing Record 47 of Set 10 | vorobyevka
# Processing Record 48 of Set 10 | provideniya
# Processing Record 49 of Set 10 | ondjiva
# Processing Record 0 of Set 11 | ugoofaaru
# Processing Record 1 of Set 11 | ylivieska
# Processing Record 2 of Set 11 | saint-pierre
# Processing Record 3 of Set 11 | hastings
# Processing Record 4 of Set 11 | dauriya
# Processing Record 5 of Set 11 | arona
# Processing Record 6 of Set 11 | bilma
# Processing Record 7 of Set 11 | kabale
# Processing Record 8 of Set 11 | lakselv
# Processing Record 9 of Set 11 | culpeper
# Processing Record 10 of Set 11 | kudahuvadhoo
# Processing Record 11 of Set 11 | san fernando
# Processing Record 12 of Set 11 | norwich
# Processing Record 13 of Set 11 | guadalupe y calvo
# Processing Record 14 of Set 11 | beipiao
# Processing Record 15 of Set 11 | liverpool
# Processing Record 16 of Set 11 | pascagoula
# Processing Record 17 of Set 11 | urumqi
# Processing Record 18 of Set 11 | sangar
# Processing Record 19 of Set 11 | rocha
# Processing Record 20 of Set 11 | valdivia
# Processing Record 21 of Set 11 | ormara
# Processing Record 22 of Set 11 | port hardy
# Processing Record 23 of Set 11 | karlshamn
# Processing Record 24 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 11 | mizdah
# Processing Record 27 of Set 11 | bathsheba
# Processing Record 28 of Set 11 | volkhovskiy
# Processing Record 29 of Set 11 | monrovia
# Processing Record 30 of Set 11 | tura
# Processing Record 31 of Set 11 | inta
# Processing Record 32 of Set 11 | sungairaya
# Processing Record 33 of Set 11 | dondo
# Processing Record 34 of Set 11 | zhuhai
# Processing Record 35 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 11 | bosobolo
# Processing Record 38 of Set 11 | nerchinskiy zavod
# Processing Record 39 of Set 11 | kathmandu
# Processing Record 40 of Set 11 | margate
# Processing Record 41 of Set 11 | caravelas
# Processing Record 42 of Set 11 | itapetinga
# Processing Record 43 of Set 11 | kahului
# Processing Record 44 of Set 11 | touros
# Processing Record 45 of Set 11 | amot
# Processing Record 46 of Set 11 | pyshma
# Processing Record 47 of Set 11 | burns lake
# Processing Record 48 of Set 11 | la quinta
# Processing Record 49 of Set 11 | nizhniy odes
# Processing Record 0 of Set 12 | abu samrah
# Processing Record 1 of Set 12 | orotukan
# Processing Record 2 of Set 12 | rio branco do sul
# Processing Record 3 of Set 12 | rjukan
# Processing Record 4 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 5 of Set 12 | yerbogachen
# Processing Record 6 of Set 12 | yumbing
# Processing Record 7 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 12 | pellerd
# Processing Record 9 of Set 12 | bobo dioulasso
# Processing Record 10 of Set 12 | ayni
# Processing Record 11 of Set 12 | mahibadhoo
# Processing Record 12 of Set 12 | buchanan
# Processing Record 13 of Set 12 | mackenzie
# Processing Record 14 of Set 12 | yumen
# Processing Record 15 of Set 12 | leshukonskoye
# Processing Record 16 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 17 of Set 12 | krasnoselkup
# Processing Record 18 of Set 12 | chaplygin
# Processing Record 19 of Set 12 | kuytun
# Processing Record 20 of Set 12 | port lincoln
# Processing Record 21 of Set 12 | inhapi
# Processing Record 22 of Set 12 | havoysund
# Processing Record 23 of Set 12 | puksoozero
# Processing Record 24 of Set 12 | trinidad
# Processing Record 25 of Set 12 | hamamatsu
# Processing Record 26 of Set 12 | bonavista
# Processing Record 27 of Set 12 | vitoria da conquista
# Processing Record 28 of Set 12 | yangambi
# Processing Record 29 of Set 12 | veraval
# Processing Record 30 of Set 12 | churapcha
# Processing Record 31 of Set 12 | saint-joseph
# Processing Record 32 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 12 | broken hill
# Processing Record 34 of Set 12 | khani
# Processing Record 35 of Set 12 | tarko-sale
# Processing Record 36 of Set 12 | wangqing
# Processing Record 37 of Set 12 | kilindoni
# Processing Record 38 of Set 12 | brits
# Processing Record 39 of Set 12 | sawakin
# Processing Record 40 of Set 12 | yaan
# Processing Record 41 of Set 12 | mazara del vallo
# Processing Record 42 of Set 12 | shupiyan
# Processing Record 43 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 44 of Set 12 | abeche
# Processing Record 45 of Set 12 | uvat
# Processing Record 46 of Set 12 | jeremie
# Processing Record 47 of Set 12 | sakakah
# Processing Record 48 of Set 12 | mount isa
# Processing Record 49 of Set 12 | kirkuk
# Processing Record 0 of Set 13 | guiuan
# Processing Record 1 of Set 13 | shingu
# Processing Record 2 of Set 13 | chernyshevskiy
# Processing Record 3 of Set 13 | porto-vecchio
# Processing Record 4 of Set 13 | daru
# Processing Record 5 of Set 13 | mahon
# Processing Record 6 of Set 13 | tocache
# Processing Record 7 of Set 13 | tilichiki
# Processing Record 8 of Set 13 | ponta delgada
# Processing Record 9 of Set 13 | haines junction
# Processing Record 10 of Set 13 | nuuk
# Processing Record 11 of Set 13 | san cristobal
# Processing Record 12 of Set 13 | dombarovskiy
# Processing Record 13 of Set 13 | aswan
# Processing Record 14 of Set 13 | bhawana
# Processing Record 15 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 13 | ukiah
# Processing Record 17 of Set 13 | obo
# Processing Record 18 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 13 | berbera
# Processing Record 21 of Set 13 | pemangkat
# Processing Record 22 of Set 13 | sechura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    barrow  71.2906 -156.7887    -27.99        76         100        2.57
# 1   mataura -46.1927  168.8643     14.83        75          99        3.87
# 2     kapaa  22.0752 -159.3190     22.18        90         100        4.12
# 3  la ronge  55.1001 -105.2842     -4.86        93         100        3.60
# 4   ushtobe  45.2514   77.9838      0.43        98         100        1.80
#
#   Country        Date
# 0      US  1675612729
# 1      NZ  1675612729
# 2      US  1675612730
# 3      CA  1675612730
# 4      KZ  1675612731

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          barrow  71.2906 -156.7887    -27.99        76         100
# 1         mataura -46.1927  168.8643     14.83        75          99
# 2           kapaa  22.0752 -159.3190     22.18        90         100
# 3        la ronge  55.1001 -105.2842     -4.86        93         100
# 4         ushtobe  45.2514   77.9838      0.43        98         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      US  1675612729
# 1              3.87      NZ  1675612729
# 2              4.12      US  1675612730
# 3              3.60      CA  1675612730
# 4              1.80      KZ  1675612731

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
latitude_values = city_data_df["Lat"]
temperature_values = city_data_df["Max Temp"]
Fig1 = plt.scatter(latitude_values, temperature_values, edgecolors="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
latitude_values = city_data_df["Lat"]
humidity_values = city_data_df["Humidity"]
Fig2 = plt.scatter(latitude_values, humidity_values, edgecolors="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
latitude_values = city_data_df["Lat"]
cloudiness_values = city_data_df["Cloudiness"]
Fig3 = plt.scatter(latitude_values, cloudiness_values, edgecolors="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
latitude_values = city_data_df["Lat"]
wind_values = city_data_df["Wind Speed"]
Fig4 = plt.scatter(latitude_values, wind_values, edgecolors="black", linewidths=1, alpha=0.8)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(x_values, y_values, title, x_label, y_label, text_coord):

    # Calculate values for linear regression equation
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate y-values for the linear regression line
    regress_values = x_values * slope + intercept

    # Formulate the linear regression equation for display
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Create scatter plot including the linear regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")

    # Add text annotation for line equation
    plt.annotate(line_eq, text_coord, fontsize=15, color='red')

    # Add chart title and labels
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Print the r-value
    print(f"The r-value is: {r_value}")

    # Show the chart
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          barrow  71.2906 -156.7887    -27.99        76         100
# 2           kapaa  22.0752 -159.3190     22.18        90         100
# 3        la ronge  55.1001 -105.2842     -4.86        93         100
# 4         ushtobe  45.2514   77.9838      0.43        98         100
# 6         qaanaaq  77.4840  -69.3632    -19.55        66           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      US  1675612729
# 2              4.12      US  1675612730
# 3              3.60      CA  1675612730
# 4              1.80      KZ  1675612731
# 6              4.05      GL  1675612731

# %%
# Show record count for cities in Northern Hemispehere
northern_hemi_df.count()
# Out:
# City          400
# Lat           400
# Lng           400
# Max Temp      400
# Humidity      400
# Cloudiness    400
# Wind Speed    400
# Country       400
# Date          400
# dtype: int64

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 mataura -46.1927  168.8643     14.83        75          99
# 5            punta arenas -53.1500  -70.9167     10.06        57          20
# 8               mahebourg -20.4081   57.7000     27.36        89          40
# 9        pontes e lacerda -15.2261  -59.3353     29.46        64          93
# 14               karratha -20.7377  116.8463     31.37        54          13
#
#          Wind Speed Country        Date
# City_ID
# 1              3.87      NZ  1675612729
# 5             13.89      CL  1675612721
# 8              1.54      MU  1675612732
# 9              2.10      BR  1675612732
# 14             6.63      AU  1675612734

# %%
# Show record count for cities in Southern Hemispehere
southern_hemi_df.count()
# Out:
# City          175
# Lat           175
# Lng           175
# Max Temp      175
# Humidity      175
# Cloudiness    175
# Wind Speed    175
# Country       173
# Date          175
# dtype: int64

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Define x-values and y-values for the plot
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function to plot the linear regression
Fig5 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Maximum Temperature on Northern Hemisphere",
                              "Latitude",
                              "Max Temperature (C)",
                              (5,-35))
# Out:
# The r-value is: -0.8648094511915152

# %%
# Linear regression on Southern Hemisphere

# Define x-values and y-values for the plot
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function to plot the linear regression
Fig6 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Maximum Temperature on Southern Hemisphere",
                              "Latitude",
                              "Max Temperature (C)",
                              (-30,10))
# Out:
# The r-value is: 0.4496880751845077

# %% [markdown]
# **Discussion about the linear relationship:**
# - The r-value of -0.86481 for linear relationship between Latitude and Maximum Temperature on Northern Hemisphere indicates a strong negative relationship. This supports the belief that as we approach the equator (latitude becomes closer to zero), the maximum temperatures rise for the cities in that area. This relationship is evident in the scatter plot as well.
# - The r-value of 0.44969 for linear relationship between Latitude and Maximum Temperature on Southern Hemisphere indicates a weak positive relationship. This indicates that the maximum temperatures of some cities drop as we move away from equator in Southern Hemisphere, however, the decline in temperatures is not very sharp and not true for majority of the data we are using.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define x-values and y-values for the plot
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Call the function to plot the linear regression
Fig7 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Humidity on Northern Hemisphere",
                              "Latitude",
                              "Humidity (%)",
                              (45,10))
# Out:
# The r-value is: 0.489934553775146

# %%
# Southern Hemisphere
# Define x-values and y-values for the plot
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Call the function to plot the linear regression
Fig8 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Humidity on Southern Hemisphere",
                              "Latitude",
                              "Humidity (%)",
                              (-25,12))
# Out:
# The r-value is: 0.24570274488743915

# %% [markdown]
# **Discussion about the linear relationship:**
# - The r-value of 0.48993 for linear relationship between Latitude and Humidity on Northern Hemisphere indicates a weak to moderate positive relationship. This indicates that the humidity level of a moderate number of cities increases as we move away from equator in Northern Hemisphere, however, this increase in humidity is not very sharp and might not be true for the majority of the data.
# - The r-value of 0.24570 for linear relationship between Latitude and Humidity on Southern Hemisphere indicates a very weak positive relationship. This indicates that there is none to very less change in humidity levels as we move away from equator in Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define x-values and y-values for the plot
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function to plot the linear regression
Fig9 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Cloudiness on Northern Hemisphere",
                              "Latitude",
                              "Cloudiness (%)",
                              (45,32))
# Out:
# The r-value is: 0.28001331215595987

# %%
# Southern Hemisphere

# Define x-values and y-values for the plot
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Call the function to plot the linear regression
Fig10 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Cloudiness on Southern Hemisphere",
                              "Latitude",
                              "Cloudiness (%)",
                              (-55,55))
# Out:
# The r-value is: 0.2778658179218428

# %% [markdown]
# **Discussion about the linear relationship:**
# - The r-value of 0.28001 for linear relationship between Latitude and Cloudiness on Northern Hemisphere indicates a very weak positive relationship. This indicates that the cloudiness in very few cities increases as we move away from equator in Northern Hemisphere, however, this change in cloudiness is not signigicant and might not be true for the majority of the data.
# - The r-value of 0.27786 for linear relationship between Latitude and Cloudiness on Southern Hemisphere indicates a very weak positive relationship. This indicates that there is none to very less change in cloudiness levels as we move away from equator in Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define x-values and y-values for the plot
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Call the function to plot the linear regression
Fig11 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Wind Speed on Northern Hemisphere",
                              "Latitude",
                              "Wind Speed (m/s)",
                              (10,15))
# Out:
# The r-value is: 0.028175403387331446

# %%
# Southern Hemisphere

# Define x-values and y-values for the plot
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Call the function to plot the linear regression
Fig12 = linear_regression_plot(x_values, y_values,
                              "Latitude vs. Wind Speed on Southern Hemisphere",
                              "Latitude",
                              "Wind Speed (m/s)",
                              (-35,15))
# Out:
# The r-value is: -0.389720883728276

# %% [markdown]
# **Discussion about the linear relationship:**
# - The r-value of 0.02818 for linear relationship between Latitude and Wind Speed on Northern Hemisphere indicates almost no relationship. This indicates that it will be insignificant to compare wind speeds as we move away from equator in Northern Hemisphere. The chart presents a good representation of this fact.
# - The r-value of -0.38972 for linear relationship between Latitude and Wind Speed on Southern Hemisphere indicates a weak negative relationship. This indicates that wind speeds tend to decrease slighly as we move awway from equator in Souther Hemisphere, however, this decrease in wind speeds is not signifcant and not true for majority of the data.
